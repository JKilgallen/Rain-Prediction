# %% [markdown]
# # Rainfall Prediction - Training a Binary Classifier
# ## Model Building and Evaluation
# As usual we need to load in the libraries, and data, we will be using.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

X_train = pd.read_csv("X_train.csv", header=None)
X_test = pd.read_csv("X_test.csv", header=None)
y_train = pd.read_csv("y_train.csv")
y_test = pd.read_csv("y_test.csv")

# %% [markdown]
# We can now import a logistic regression model from sklearn, and train it on the data we've prepared.

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(solver='liblinear')
fit = model.fit(X_train, y_train['RainTomorrow'].values.ravel())

# %% [markdown]
# Now, we can use `predict` to see whether or not our model expects it to rain on the days in our test data set.

# %%
from sklearn.metrics import accuracy_score

y_pred = model.predict(X_test)
y_pred
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %% [markdown]
# We can also use `predict_proba` to get our models probability estimates for rain on each of the days in the test dataset.

# %%
model.predict_proba(X_test)
# Out:
# array([[0.93853527, 0.06146473],
#        [0.97598477, 0.02401523],
#        [0.78287216, 0.21712784],
#        ...,
#        [0.96370134, 0.03629866],
#        [0.6662715 , 0.3337285 ],
#        [0.97254134, 0.02745866]])

# %% [markdown]
# sklearn also has a function `accuracy_score` which allows us to test the accuracy of our model.

# %%
accuracy_score(y_test['RainTomorrow'], y_pred)
# Out:
# 0.8328000281303843

# %% [markdown]
# Finally, we can examine the weights generated by our model to see which features it assigns importance to.

# %%
features = np.load("features.npy")
dict(zip(features, model.coef_[0]))
# Out:
# {'Cloud3pm': 0.7608707389905341,
#  'Cloud9am': 0.16433916944567153,
#  'Day': -0.03228726635302278,
#  'Evaporation': 0.059189749181818165,
#  'Humidity3pm': 1.907437264584414,
#  'Humidity9am': 0.5181593001392079,
#  'Location=Adelaide': 0.600732352226965,
#  'Location=Albany': -0.1807678664782725,
#  'Location=Albury': 0.18989802838965175,
#  'Location=AliceSprings': -0.13483391681985654,
#  'Location=BadgerysCreek': 0.28040887308700985,
#  'Location=Ballarat': -0.3720034042058957,
#  'Location=Bendigo': -0.006899845430245617,
#  'Location=Brisbane': 0.6071459220511582,
#  'Location=Cairns': 0.2745590074853293,
#  'Location=Canberra': -0.12246779499984588,
#  'Location=Cobar': 0.033032452339599845,
#  'Location=CoffsHarbour': 0.04710452261352329,
#  'Location=Dartmoor': 0.08102066926179907,
#  'Location=Darwin': -0.17749131910176014,
#  'Location=GoldCoast': 0.10222901397832544,
#  'Location=Hobart': -0.4197597923105655,
#  'Location=Katherine': -0.27402073554645834,
#  'Location=Launceston': -0.38286381021118543,
#  'Location=Melbourne': -0.1433230160571819,
#  'Location=MelbourneAirport': -0.5737916246086773,
#  'Location=Mildura': -0.20972623513196764,
#  'Location=Moree': -0.0015636258679024516,
#  'Location=MountGambier': -0.07790927526243294,
#  'Location=MountGinini': -0.32462568281650195,
#  'Location=Newcastle': -0.13394467591755724,
#  'Location=Nhil': -0.2462686965796315,
#  'Location=NorahHead': -0.293308049135475,
#  'Location=NorfolkIsland': -0.5481081146013707,
#  'Location=Nuriootpa': -0.12181406160827471,
#  'Location=PearceRAAF': 0.2467448193945556,
#  'Location=Penrith': 0.4547561061779185,
#  'Location=Perth': 0.46564483651182537,
#  'Location=PerthAirport': 0.32258232308658075,
#  'Location=Portland': -0.12563659926194895,
#  'Location=Richmond': 0.21346306891881167,
#  'Location=Sale': -0.3799887121139662,
#  'Location=SalmonGums': 0.37806538019330993,
#  'Location=Sydney': -0.030288484511681656,
#  'Location=SydneyAirport': -0.13268332895255774,
#  'Location=Townsville': -0.4034863389837057,
#  'Location=Tuggeranong': 0.16372145087455173,
#  'Location=Uluru': -0.02390201561733614,
#  'Location=WaggaWagga': -0.046229966682808994,
#  'Location=Walpole': 0.22213415113321405,
#  'Location=Watsonia': -0.38533498844965236,
#  'Location=Williamtown': 0.3064438657272782,
#  'Location=Witchcliffe': 0.5620521169396651,
#  'Location=Wollongong': -0.6267406244827509,
#  'Location=Woomera': -0.3454647346684025,
#  'MaxTemp': -0.4243304397631247,
#  'MinTemp': 0.3502921671528869,
#  'Month': -0.010808273433485015,
#  'Pressure3pm': -2.0265384485623956,
#  'Pressure9am': 0.8322939363925217,
#  'RainToday=No': -1.0228103781850422,
#  'RainToday=Yes': -0.6706979978381145,
#  'Rainfall': 0.3245848321523781,
#  'Sunshine': -0.797338763204596,
#  'Temp3pm': -0.7701121131376744,
#  'Temp9am': 0.5522750016338174,
#  'Unnamed: 0': -0.16957331311086737,
#  'WindDir3pm=E': -0.22486041604069826,
#  'WindDir3pm=ENE': -0.11803002922258006,
#  'WindDir3pm=ESE': -0.24028983388235314,
#  'WindDir3pm=N': 0.2469052333483993,
#  'WindDir3pm=NE': -0.2139306621626582,
#  'WindDir3pm=NNE': 0.056733460488303966,
#  'WindDir3pm=NNW': 0.3116524206120252,
#  'WindDir3pm=NW': 0.20555813827020986,
#  'WindDir3pm=S': -0.19152597413482778,
#  'WindDir3pm=SE': -0.09609575604920347,
#  'WindDir3pm=SSE': -0.341236470842135,
#  'WindDir3pm=SSW': -0.2024146925338023,
#  'WindDir3pm=SW': -0.37436294268648546,
#  'WindDir3pm=W': -0.17938986294474019,
#  'WindDir3pm=WNW': -0.013005192903399767,
#  'WindDir3pm=WSW': -0.31921579534116434,
#  'WindDir9am=E': -0.09682396455857249,
#  'WindDir9am=ENE': 0.08835135644630096,
#  'WindDir9am=ESE': -0.22744149606936848,
#  'WindDir9am=N': 0.02439945446302863,
#  'WindDir9am=NE': 0.07381714449073562,
#  'WindDir9am=NNE': 0.238095341045322,
#  'WindDir9am=NNW': -0.053551936253774114,
#  'WindDir9am=NW': -0.034871265702937006,
#  'WindDir9am=S': -0.37935237790525383,
#  'WindDir9am=SE': -0.2536541628287443,
#  'WindDir9am=SSE': -0.3320080299943789,
#  'WindDir9am=SSW': -0.2158853924409034,
#  'WindDir9am=SW': -0.15908086079983247,
#  'WindDir9am=W': -0.13562199359594232,
#  'WindDir9am=WNW': -0.08095150551248724,
#  'WindDir9am=WSW': -0.1489286868084925,
#  'WindGustDir=E': -0.13032576014808903,
#  'WindGustDir=ENE': -0.09492876714947797,
#  'WindGustDir=ESE': -0.05550490913874179,
#  'WindGustDir=N': -0.08433169395170262,
#  'WindGustDir=NE': -0.21276476292553456,
#  'WindGustDir=NNE': -0.2578994621098102,
#  'WindGustDir=NNW': -0.04698502248389609,
#  'WindGustDir=NW': -0.059917091305831165,
#  'WindGustDir=S': -0.023307069471087377,
#  'WindGustDir=SE': -0.11243303859956498,
#  'WindGustDir=SSE': -0.07109374529267781,
#  'WindGustDir=SSW': -0.10614729066227432,
#  'WindGustDir=SW': -0.11814297178977529,
#  'WindGustDir=W': -0.06287613111218986,
#  'WindGustDir=WNW': -0.12939614739712366,
#  'WindGustDir=WSW': -0.12745451248729692,
#  'WindGustSpeed': 1.418034292196321,
#  'WindSpeed3pm': -0.39293673357693387,
#  'WindSpeed9am': 0.015565850956018605,
#  'Year': 0.08103544356319364}
